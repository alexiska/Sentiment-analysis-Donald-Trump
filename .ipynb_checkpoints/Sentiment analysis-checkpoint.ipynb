# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
df1 = pd.read_csv('trump-tweets-raw(data-world).csv',encoding='Latin-1')

# %%
df = pd.read_csv('Donald-Tweets!.csv',encoding='Latin-1')

# %%
df.head()
# Out:
#        Date      Time                                         Tweet_Text  \
# 0  16-11-11  15:26:37  Today we express our deepest gratitude to all ...
# 1  16-11-11  13:33:35  Busy day planned in New York. Will soon be mak...
# 2  16-11-11  11:14:20  Love the fact that the small groups of protest...
# 3  16-11-11   2:19:44  Just had a very open and successful presidenti...
# 4  16-11-11   2:10:46  A fantastic day in D.C. Met with President Oba...
#
#    Type Media_Type   Hashtags      Tweet_Id  \
# 0  text      photo  ThankAVet  7.970000e+17
# 1  text        NaN        NaN  7.970000e+17
# 2  text        NaN        NaN  7.970000e+17
# 3  text        NaN        NaN  7.970000e+17
# 4  text        NaN        NaN  7.970000e+17
#
#                                            Tweet_Url  \
# 0  https://twitter.com/realDonaldTrump/status/797...
# 1  https://twitter.com/realDonaldTrump/status/797...
# 2  https://twitter.com/realDonaldTrump/status/797...
# 3  https://twitter.com/realDonaldTrump/status/796...
# 4  https://twitter.com/realDonaldTrump/status/796...
#
#    twt_favourites_IS_THIS_LIKE_QUESTION_MARK  Retweets  Unnamed: 10  \
# 0                                     127213     41112          NaN
# 1                                     141527     28654          NaN
# 2                                     183729     50039          NaN
# 3                                     214001     67010          NaN
# 4                                     178499     36688          NaN
#
#    Unnamed: 11
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df[df['Date']=='16-08-08']
# Out:
#           Date      Time                                         Tweet_Text  \
# 1140  16-08-08  23:18:42  As Senator Clinton promised 200,000 jobs in Up...
# 1141  16-08-08  22:45:33  Many people are saying that the Iranians kille...
# 1142  16-08-08  22:43:56           Thank you Newt!  https://t.co/Acg0hMvrpr
# 1143  16-08-08  22:27:02  Thank you Congressman Steven Palazzo! https://...
# 1144  16-08-08  22:24:09  Thank you Senator David Perdue!\nhttps://t.co/...
# 1145  16-08-08  22:20:31  Thank you @RepLouBarletta!\nhttps://t.co/bre8u...
# 1146  16-08-08  22:15:44  Thank you @NFIB- together we will #MakeAmerica...
# 1147  16-08-08  22:12:21                Thank you!  https://t.co/4p0hzpkVWF
# 1148  16-08-08  22:06:25           Thank you Alex!  https://t.co/c2uIa7mndP
# 1149  16-08-08  20:14:57  RT @NFIB: .@NFIB encouraged by @realDonaldTrum...
# 1150  16-08-08  15:20:44  My economic policy speech will be carried live...
# 1151  16-08-08  13:28:20  Join me in Fayetteville, North Carolina tomorr...
# 1152  16-08-08   0:05:54  #ICYMI: "Will Media Apologize to Trump?" https...
#
#       Type Media_Type               Hashtags      Tweet_Id  \
# 1140  text      photo                    NaN  7.630000e+17
# 1141  text        NaN                    NaN  7.630000e+17
# 1142  text        NaN                    NaN  7.630000e+17
# 1143  text      photo                    NaN  7.630000e+17
# 1144  link      photo                    NaN  7.630000e+17
# 1145  text      photo                    NaN  7.630000e+17
# 1146  text        NaN  MakeAmericaGreatAgain  7.630000e+17
# 1147  text        NaN                    NaN  7.630000e+17
# 1148  text        NaN                    NaN  7.630000e+17
# 1149  link        NaN       taxplan;smallbiz  7.630000e+17
# 1150  text        NaN                    NaN  7.630000e+17
# 1151  text        NaN                    NaN  7.630000e+17
# 1152  link        NaN                  ICYMI  7.620000e+17
#
#                                               Tweet_Url  \
# 1140  https://twitter.com/realDonaldTrump/status/762...
# 1141  https://twitter.com/realDonaldTrump/status/762...
# 1142  https://twitter.com/realDonaldTrump/status/762...
# 1143  https://twitter.com/realDonaldTrump/status/762...
# 1144  https://twitter.com/realDonaldTrump/status/762...
# 1145  https://twitter.com/realDonaldTrump/status/762...
# 1146  https://twitter.com/realDonaldTrump/status/762...
# 1147  https://twitter.com/realDonaldTrump/status/762...
# 1148  https://twitter.com/realDonaldTrump/status/762...
# 1149  https://twitter.com/realDonaldTrump/status/762...
# 1150  https://twitter.com/realDonaldTrump/status/762...
# 1151  https://twitter.com/realDonaldTrump/status/762...
# 1152  https://twitter.com/realDonaldTrump/status/762...
#
#       twt_favourites_IS_THIS_LIKE_QUESTION_MARK  Retweets  Unnamed: 10  \
# 1140                                      17785      7962          NaN
# 1141                                      34214     13469          NaN
# 1142                                      25622      9019          NaN
# 1143                                      16813      6173          NaN
# 1144                                      15824      6197          NaN
# 1145                                      13848      4721          NaN
# 1146                                      13526      4574          NaN
# 1147                                      12272      3654          NaN
# 1148                                      13384      4291          NaN
# 1149                                       8115      3356          NaN
# 1150                                      21645      5528          NaN
# 1151                                      13303      4142          NaN
# 1152                                      19614      8169          NaN
#
#       Unnamed: 11
# 1140          NaN
# 1141          NaN
# 1142          NaN
# 1143          NaN
# 1144          NaN
# 1145          NaN
# 1146          NaN
# 1147          NaN
# 1148          NaN
# 1149          NaN
# 1150          NaN
# 1151          NaN
# 1152          NaN

# %%
df1.tail()
# Out:
#                       id   source  \
# 2337  734938503541325825  Android
# 2338  734936659851128832  Android
# 2339  734903156589645824   iPhone
# 2340  734892328637325312  Android
# 2341  734742416494845952  Android
#
#                                                    text               created
# 2337  Much of the money I have raised for our vetera...  2016-05-24T02:46:08Z
# 2338  While under no obligation to do so, I have rai...  2016-05-24T02:38:48Z
# 2339  Join me in California or Montana!\n5/25/16: An...  2016-05-24T00:25:41Z
# 2340  I will be interviewed on @oreillyfactor at 8:0...  2016-05-23T23:42:39Z
# 2341  In trade, military and EVERYTHING else, it wil...  2016-05-23T13:46:57Z

# %%
#Create two new columns for date and time 
import re
df1['Date'] = df1['created'].str.replace(r'T(\d\d):(\d\d):(\d\d)Z','')
df1['Time'] = df1['created'].str.replace(r'(\d\d\d\d)-(\d\d)-(\d\d)T','').str.replace(r'Z','')

# %%
#Remove uncessary columns 
columns = ['Type','Media_Type','Hashtags','Tweet_Id','Tweet_Url','twt_favourites_IS_THIS_LIKE_QUESTION_MARK','Retweets','Unnamed: 10','Unnamed: 11']
df = df.drop(columns,axis=1)
df.tail()
# Out:
#           Date      Time                                         Tweet_Text
# 7370  15-07-16  13:10:00  I loved firing goofball atheist Penn @pennjill...
# 7371  15-07-16  10:18:31  I hear @pennjillette show on Broadway is terri...
# 7372  15-07-16  10:10:17  Irrelevant clown @KarlRove sweats and shakes n...
# 7373  15-07-16   9:44:07  "@HoustonWelder: Donald Trump is one of the se...
# 7374  15-07-16   0:21:25  RT @marklevinshow: Trump: Rove is a clown and ...

# %%
columns = ['id','source','created']
df1 = df1.drop(columns,axis=1)
df1
# Out:
#                                                    text        Date      Time
# 0     The #AmazonWashingtonPost, sometimes referred ...  2017-06-28  13:06:14
# 1     Some of the Fake News Media likes to say that ...  2017-06-28  10:58:59
# 2     The failing @nytimes writes false story after ...  2017-06-28  10:49:22
# 3     I just finished a great meeting with the Repub...  2017-06-27  22:27:48
# 4     With ZERO Democrats to help, and a failed, exp...  2017-06-27  22:22:55
# ...                                                 ...         ...       ...
# 2337  Much of the money I have raised for our vetera...  2016-05-24  02:46:08
# 2338  While under no obligation to do so, I have rai...  2016-05-24  02:38:48
# 2339  Join me in California or Montana!\n5/25/16: An...  2016-05-24  00:25:41
# 2340  I will be interviewed on @oreillyfactor at 8:0...  2016-05-23  23:42:39
# 2341  In trade, military and EVERYTHING else, it wil...  2016-05-23  13:46:57
#
# [2342 rows x 3 columns]

# %%
#Update the year with 4-digit
df['Date'] = df['Date'].str.replace(r'^()','20')
df.tail()
# Out:
#             Date      Time                                         Tweet_Text
# 7370  2015-07-16  13:10:00  I loved firing goofball atheist Penn @pennjill...
# 7371  2015-07-16  10:18:31  I hear @pennjillette show on Broadway is terri...
# 7372  2015-07-16  10:10:17  Irrelevant clown @KarlRove sweats and shakes n...
# 7373  2015-07-16   9:44:07  "@HoustonWelder: Donald Trump is one of the se...
# 7374  2015-07-16   0:21:25  RT @marklevinshow: Trump: Rove is a clown and ...

# %%
#Rename & capatilize first letter of a column
df.rename(columns={'Tweet_Text':'Text'}, inplace=True)
df1.rename(columns={'text':'Text'}, inplace=True)

# %%
#Change column order 
#Change the time format from x:xx:xx to xx:xx:xx
#and merge the dataframe together 

df = df[['Text','Date','Time']]
df['Time']=df['Time'].str.replace(r'^(\d):(\d\d):(\d\d)',r'0\1:\2:\3')

# %%
df.tail() #2016-11 2015-07
#df[df['Date'] == '2016-11-11']
# Out:
#                                                    Text        Date      Time
# 7370  I loved firing goofball atheist Penn @pennjill...  2015-07-16  13:10:00
# 7371  I hear @pennjillette show on Broadway is terri...  2015-07-16  10:18:31
# 7372  Irrelevant clown @KarlRove sweats and shakes n...  2015-07-16  10:10:17
# 7373  "@HoustonWelder: Donald Trump is one of the se...  2015-07-16  09:44:07
# 7374  RT @marklevinshow: Trump: Rove is a clown and ...  2015-07-16  00:21:25

# %%
df1.tail() #2017-06 2016-05
df1[df1['Date'] == '2016-11-11']
# Out:
#                                                    Text        Date      Time
# 1791  Today we express our deepest gratitude to all ...  2016-11-11  15:26:37
# 1792  Busy day planned in New York. Will soon be mak...  2016-11-11  13:33:35
# 1793  Love the fact that the small groups of protest...  2016-11-11  11:14:20
# 1794  Just had a very open and successful presidenti...  2016-11-11  02:19:44
# 1795  A fantastic day in D.C. Met with President Oba...  2016-11-11  02:10:46

# %%
import re
from textblob import TextBlob

merged = pd.concat([df,df1])

def cleaning(x):
    
    
  
    x = re.sub(r"http.+",'', x) #remove URL
    #x = re.sub(r"(\w)([A-Z])", r"\1 \2",x) #Space before capital letters
    x = re.sub(r"[^a-zA-Z]",' ', x) # Remove non-letters
    #x = re.sub(r"\s+",' ', x) # replace several spaces with one space
    
    x = x.strip()
    #x.replace("@\S*",'',regex=True,inplace=True)
    #x.replace("[\n]",'',regex=True,inplace=True)
    return x
test = merged.copy()#df1[df1['Date']=='2016-08-08'].copy()
test = test.reset_index()
test['Text'] = test.apply(lambda x: cleaning(x['Text']),axis=1)

# %%
pol = []
sub = []
for i, text in enumerate(test['Text']):
    pol.append(TextBlob(text).sentiment[0])
    sub.append(TextBlob(text).sentiment[1])

# %%
df_sentiment = pd.DataFrame({'polarity':pol,
                         'subjectivity':sub})

# Concatenate the two dataframes into one
df = pd.concat([test,df_sentiment], axis=1)
df.sort_values(by='Date',inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-e344af421cac> in <module>
#       2                          'subjectivity':sub})
#       3
# ----> 4 test.drop(columns=['index'],inplace=True)
#       5 df = pd.concat([test,df_sentiment], axis=1)
#       6 df.sort_values(by='Date',inplace=True)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4168             level=level,
#    4169             inplace=inplace,
# -> 4170             errors=errors,
#    4171         )
#    4172
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['index'] not found in axis"

# %%
text2016 = df[(df['Date'] >='2016-01-01') & (df['Date'] >='2016-12-31')]['Text']
lst_text = []
lst_text.append(' '.join(text for text in text2016))

fig, (ax1,ax2) = plt.subplot(1,2,figsize=(10,6))
wordcloud = WordCloud(max_words=100, background_color="ivory").generate(lst_text[0])
plt.imshow(wordcloud, interpolation='bilinear')
ax1.axis("off")
ax1.title('2016 before president')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-82455cb0fcd8> in <module>
# ----> 1 text2016 = df[(df['Date'] >='2016-01-01') & (df['Date'] >='2016-12-31')]['Text']
#       2 lst_text = []
#       3 lst_text.append(' '.join(text for text in text2016))
#       4
#       5 fig, (ax1,ax2) = plt.subplot(1,2,figsize=(10,6))
#
# NameError: name 'df' is not defined

# %%
text2017 = df[(df['Date'] >='2017-01-01') & (df['Date'] >='2017-06-15')]['Text']
lst_text = []
lst_text.append(' '.join(text for text in text2017))

wordcloud = WordCloud(max_words=100, background_color="ivory").generate(lst_text[0])
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title('2017 during president')
plt.show()

# %%
df['date'] = df['Date']+' '+df['Time']
df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9717 entries, 7353 to 7375
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         9717 non-null   int64
#  1   Text          9717 non-null   object
#  2   Date          9717 non-null   object
#  3   Time          9717 non-null   object
#  4   polarity      9717 non-null   float64
#  5   subjectivity  9717 non-null   float64
#  6   date          9717 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 607.3+ KB

# %%
df.drop(columns=['index'],inplace=True)

# %%
fig, (ax1,ax2) = plt.subplots(1,2)
sentiment_week = df.groupby(pd.Grouper(key='date',freq='w')).mean()
sentiment_day = df.groupby(pd.Grouper(key='date',freq='d')).mean()

sentiment_day.plot(alpha=0.7, ax=ax1,figsize=(12,4))
sentiment_week.plot(alpha=0.7, ax=ax2)
# Out:
# <AxesSubplot:xlabel='date'>

# %%
test = df1[df1['Date']=='2016-08-08'].copy()
for i in test['Text']:
    print(i)

#re.sub(r"(?<=\s(http.)).*?(?=\s)",'',test['Text'])
#test['Text'].replace("http.+",'',regex=True,inplace=True)
#test['Text'].replace("@\S*",'',regex=True,inplace=True)
#test['Text'].replace("[\n]",'',regex=True,inplace=True)
#test['Text']
# Out:
# My economic policy speech will be carried live at 12:15 P.M. Enjoy!
# Join me in Fayetteville, North Carolina tomorrow evening at 6pm. Tickets now available at: https://t.co/Z80d4MYIg8
# #ICYMI: "Will Media Apologize to Trump?" https://t.co/ia7rKBmioA
# 'As Senator Clinton promised 200,000 jobs in Upstate New York - her efforts fell flat.' https://t.co/I2WqZb5N8P https://t.co/i5S3mtJWpe
# Many people are saying that the Iranians killed the scientist who helped the U.S. because of Hillary Clinton's hacked emails.
# Thank you Newt!  https://t.co/Acg0hMvrpr
# Thank you Congressman Steven Palazzo! https://t.co/R5Z4CGfjqJ https://t.co/XGSIJJQiGJ
# Thank you Senator David Perdue!
# https://t.co/d0dCUZ20jf https://t.co/LmfiGByFPb
# Thank you @RepLouBarletta!
# https://t.co/bre8u93vac https://t.co/eKtSXUw51R
# Thank you @NFIB- together we will #MakeAmericaGreatAgain!  https://t.co/wQQIHQKsdK
# Thank you!  https://t.co/4p0hzpkVWF
# Thank you Alex!  https://t.co/c2uIa7mndP

# %%
test['Text'][2235]
# Out:
# 'Thank you @RepLouBarletta!\nhttps://t.co/bre8u93vac https://t.co/eKtSXUw51R'

# %%
df[df['Date']=='16-08-08']
# Out:
# Empty DataFrame
# Columns: [index, Text, Date, Time, polarity, subjectivity, date]
# Index: []

# %%
df1s = df1.sort_values(by=['Date','Time'])

# %%
df1s[df1s['Date']=='2016-08-08']
# Out:
#                                                    Text        Date      Time
# 401   #ICYMI: "Will Media Apologize to Trump?" https...  2016-08-08  00:05:54
# 400   Join me in Fayetteville, North Carolina tomorr...  2016-08-08  13:28:20
# 399   My economic policy speech will be carried live...  2016-08-08  15:20:44
# 2238           Thank you Alex!  https://t.co/c2uIa7mndP  2016-08-08  22:06:25
# 2237                Thank you!  https://t.co/4p0hzpkVWF  2016-08-08  22:12:21
# 2236  Thank you @NFIB- together we will #MakeAmerica...  2016-08-08  22:15:44
# 2235  Thank you @RepLouBarletta!\nhttps://t.co/bre8u...  2016-08-08  22:20:31
# 2234  Thank you Senator David Perdue!\nhttps://t.co/...  2016-08-08  22:24:09
# 2233  Thank you Congressman Steven Palazzo! https://...  2016-08-08  22:27:02
# 2232           Thank you Newt!  https://t.co/Acg0hMvrpr  2016-08-08  22:43:56
# 2231  Many people are saying that the Iranians kille...  2016-08-08  22:45:33
# 2230  'As Senator Clinton promised 200,000 jobs in U...  2016-08-08  23:18:42

# %%
df[df['Date']<='16-05-22'] #2016-11 2015-07
# Out:
# Empty DataFrame
# Columns: [index, Text, Date, Time, polarity, subjectivity, date]
# Index: []
